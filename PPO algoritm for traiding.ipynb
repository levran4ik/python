# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import gym

# %%
# Переменные класса торговли (Trade_emulator)
NAME = 'BR Splice_TF'
TIMEFRAME = '5' #'16385' #'16408'
MODE = 'train' #'test'
NUMBER_ACTION = 3 # {0: вне рынка,1: buy, 2:sell}
NROWS = 30000 #количество бар истории
env_name = NAME+TIMEFRAME

# Переменные функции потерь
EPSILON_CLIP        = 0.2
#весовые коэффициенты потерь
C0_LOSS_ACTOR       = 30
C1_LOSS_CRITIC      = 30 
C2_LOSS_ENTROPY     = 0.1

#расчет Advantage и Value_target 
GAMMA               = 0.99
GAE_LAMBDA          = 0.95

PPO_BATCH           =128 #размер выборки
EPOCH               =10  #количество эпох

MAX_ITERATION       = 100000 #маскимальное количество проходов

# %%
class Trade_emulator:
    def __init__(self, env_name):
        # переменные для анализа
        columns_clas = ['AC_L', 'AC_S','AMA_L', 'AMA_S', 'AO_L', 'AO_S', 'Bears_L', 'Bulls_S', 'CCI_L',
                       'CCI_S', 'DEMA_L', 'DEMA_S', 'DeM_L', 'DeM_S', 'Envel_L', 'Envel_S',
                       'FrAMA_L', 'FrAMA_S', 'MA_L', 'MA_S', 'MACD_L', 'MACD_S', 'RSI_L',
                       'RSI_S', 'RVI_L', 'RVI_S', 'SAR_L', 'SAR_S', 'Stoch_L', 'Stoch_S',
                       'TEMA_L', 'TEMA_S', 'TRIX_L', 'TRIX_S', 'WPR_L', 'WPR_S']
        self.space = len(columns_clas)
        self.number_action = NUMBER_ACTION
        
        # загрузка истории котировок
        df_instr = pd.read_csv(env_name+'.csv', encoding='utf-16', header=0, sep=';',nrows=NROWS)
        df_instr['del_Open'] = -df_instr['Open'].diff().shift(1) #считаем изменение цены открытия от хвоста к 0
        df_instr = df_instr[2:] # удаляем кривые значения в начале и в конце истории
        df_instr.reset_index(inplace=True, drop=True)  #сбрасываем индекс
        
        #делим на подвыборки
        NTrainVal=len(df_instr)//5              
        
        if (MODE == 'train'):
            # отбираем только нужные для обучения столбцы
            self.X_train_rl = df_instr[columns_clas].iloc[NTrainVal:].copy().values/100
            self.Rew_train = df_instr['del_Open'].iloc[NTrainVal:].copy().values 
        else:
            self.X_train_rl = df_instr[columns_clas].iloc[:NTrainVal].copy().values/100
            self.Rew_train = df_instr['del_Open'].iloc[:NTrainVal].copy().values   
    
    def action_space(self):
        def n(self):
            return(self.number_action)
        return(self.number_action)
    
    def action_sample(self):
        return(np.random.randint(self.number_action))
    
    def observation_space(self):
        return(self.space)
    
    def reset(self):
        number_step = 1000
        self.done = False
        # фиксируем границы интервала и текущий шаг
        self.Start_step = np.random.randint(number_step,self.X_train_rl.shape[0])
        self.Stop_step = self.Start_step-number_step
        self.Current_step = self.Start_step
        return(self.X_train_rl[self.Current_step])
    
    def step(self,action):
        
        curent_state = self.X_train_rl[self.Current_step] # фиксируем текущее состояние
        
        if self.done: # если шаги закончились
            reward = 0  
            new_state = curent_state
            return(new_state, reward, self.done, curent_state)
        
       # отрабатываем сигнал  
        if action == 0: # вне рынка
            reward = 0
        elif action == 1: # Buy
            reward = self.Rew_train[self.Current_step]
        elif action == 2: # Sell
            reward = -self.Rew_train[self.Current_step]
        
        # переходим на новый шаг
        self.Current_step-=1

        if self.Current_step==self.Stop_step: # если дошли до конца интервала
            self.done = True # сигнал об окончании

        new_state = self.X_train_rl[self.Current_step]
        
        return (new_state, reward, self.done, curent_state)

# %%
#преобразование массива softmax в onehot
def policy_to_onehot(pol):
    b = np.zeros_like(pol)
    a = np.argmax(pol, axis=-1)
    if len(b.shape)>1:       
        b[np.arange(a.size),a] = 1
    else:
        b[a] = 1
    return(b)

# функция потерь Actor
def loss_Actor(y_true,y_pred):
    (pol_old_onehot, pol_old, adv) = tf.split(y_true, num_or_size_splits=[-1,1,1], axis=-1)
    pol_new_full = y_pred
    
    # берем прошлые и соответствующие им новые вероятности Action
    pol_new = K.max(pol_new_full*pol_old_onehot, axis=1, keepdims=True)

    # считаем surrogate losses 
    ratio = pol_new/pol_old
    L_clip = K.mean(K.minimum(ratio*adv,K.clip(ratio, min_value=1 - EPSILON_CLIP, max_value=1 + EPSILON_CLIP)*adv),axis=-1)
    
    # считаем энтропию
    entropy =-K.sum(pol_new * K.log(pol_new+ 1e-20),axis=1)
    
    # итоговая потеря
    loss = K.mean(C0_LOSS_ACTOR*L_clip+C2_LOSS_ENTROPY*entropy)
    return(-loss) # т.к. потеря минимизаруется

# рабочая модель 
def get_model_ActorCritic(input_d,out_d):
    state_input = Input(shape=input_d, dtype = 'float32')
    dense1 = Dense(128, activation='relu')(state_input)
    dense2 = Dense(128, activation='relu')(dense1)
    Policy_prediction = Dense(out_d, activation='softmax', name='Actor')(dense2)
    V_prediction = Dense(1, activation='tanh', name='Critic')(dense2)
    model = Model(state_input,[Policy_prediction, V_prediction])
    model.compile(optimizer='rmsprop',
                  loss={'Actor': loss_Actor,
                        'Critic':'mse'},
                  loss_weights = {'Actor':1.,
                                  'Critic':C1_LOSS_CRITIC})
    return(model)

# расчет Value и Advantage
def get_Vtarget_Advantage(val, next_val, rew, mas, gamma=GAMMA, lmbda=GAE_LAMBDA):
    val = val + [next_val]
    vtarg = []
    gae = 0
    for i in reversed(range(len(rew))):
        delta = rew[i] + gamma * val[i + 1] * mas[i] - val[i]
        gae = delta + gamma * lmbda * mas[i] * gae
        vtarg.insert(0, gae + val[i])

    adv = np.array(vtarg) - val[:-1]
    return (vtarg, (adv - np.mean(adv)) / (np.std(adv) + 1e-20))


# Тестирование модели
def test_reward():
    state = env.reset()
    done = False
    total_reward = 0
    while not done:
        action_probs,_ = model_ActorCritic.predict_on_batch(state[None,:])
        action = np.argmax(action_probs)
        next_state, reward, done, _ = env.step(action)
        state = next_state
        total_reward += reward
    return total_reward

#Статистика
def record(iters, glob_reward, AC_loss):
    """Helper function to store score and print statistics.
    """
    avg_reward = np.mean([test_reward() for _ in range(3)])
    #ep_reward = test_reward()
    
    if glob_reward == 0:
        glob_reward = avg_reward
    else:
        glob_reward = glob_reward * 0.99 + avg_reward * 0.01
    #Печатаем каждый 100 проход для экономии места
    if (iters%100 == 0):
        print(
              f"Iters: {iters} | "
              f"Global MA Reward: {round(glob_reward,4)} | "
              f"AVG Episode Reward: {round(avg_reward,4)} | "
              f"Loss: {round(AC_loss,4)}"
              )
    return(glob_reward)

# %%
# Создаем рабочую среду
env = Trade_emulator(env_name)
state_dims = env.observation_space()
n_actions = env.action_space()

# Создаем модель
model_ActorCritic = get_model_ActorCritic(state_dims,n_actions)

# %%
env = gym.make('CartPole-v0')
state_dims = env.observation_space.shape[0]
n_actions = env.action_space.n

model_ActorCritic = get_model_ActorCritic(state_dims,n_actions)
MAX_ITERATION = 10000

# %%
# %%time
global_reward = 0  #среднее вознаграждение
best_reward   = 0  #лучшее вознаграждение
for iteration in range(MAX_ITERATION):  
    # обнуляем историю
    states = []
    actions = []
    values = []
    masks = []
    rewards = []
    policys = []
    
    # создаем окружение
    state = env.reset()
    done = False
    
    # прогоняем один эпизод
    while (not done):
        Policy_pred,V_pred = model_ActorCritic.predict_on_batch(state[None,:])
        policy = Policy_pred.numpy().ravel()
        value = V_pred.numpy()[0][0]

        action = np.random.choice(n_actions, p=policy)
        new_state, reward, done, curent_state = env.step(action)
        mask = (1- done)

        states.append(state)
        actions.append(action)
        values.append(value)
        masks.append(mask)
        rewards.append(reward)
        policys.append(policy)

        state = new_state
    #считаем последнее значение value
    _,next_V_pred = model_ActorCritic.predict_on_batch(state[None,:])
    next_value = next_V_pred.numpy()[0][0]
    
    #считаем Value и Advantage
    vtargets, advantages = get_Vtarget_Advantage(values, next_value, rewards, masks, gamma=GAMMA, lmbda=GAE_LAMBDA)
    
    #делаем склейку данных, для передачи Advantage в функцию потерь
    policy_targets = np.concatenate((policy_to_onehot(policys),np.amax(policys, axis=1)[:,None], np.array(advantages)[:,None]), axis=-1)
    
    # учим сеть
    ActorCritic_loss = model_ActorCritic.fit([states], [policy_targets, np.array(vtargets)[:,None]],
                                              verbose=0, shuffle=True, epochs=EPOCH, batch_size=PPO_BATCH)
    
    # Считаем награду и печатаем статистику
    global_reward = record(iteration,global_reward,ActorCritic_loss.history['loss'][-1])
    
    # сохраняем лучший результат
    if global_reward > best_reward:
        print('++++++++++++++++++ best reward=',round(global_reward,4),'++++++++++++++++++++++')
        #model_ActorCritic.save('best_{}_{}_{}.hdf5'.format(env_name,iteration, round(global_reward,4)))
        best_reward = global_reward
    # сохраняем каждый 500 проход
    if (iteration%500 == 0):
        model_ActorCritic.save('curent_{}_{}_{}.hdf5'.format(env_name,iteration, round(global_reward,4)))
# Out:
# Iters: 0 | Global MA Reward: 1.81 | AVG Episode Reward: 1.81 | Loss: -1.8057
# ++++++++++++++++++ best reward= 1.81 ++++++++++++++++++++++
# Iters: 100 | Global MA Reward: 1.0367 | AVG Episode Reward: 0.12 | Loss: 0.965
# Iters: 200 | Global MA Reward: 0.7488 | AVG Episode Reward: -1.7767 | Loss: -1.851
# Iters: 300 | Global MA Reward: 0.5709 | AVG Episode Reward: -0.09 | Loss: -3.9681
# Iters: 400 | Global MA Reward: 0.5449 | AVG Episode Reward: -0.4533 | Loss: 1.3794
# Iters: 500 | Global MA Reward: 0.5478 | AVG Episode Reward: 0.5067 | Loss: -1.1681
# Iters: 600 | Global MA Reward: 0.6747 | AVG Episode Reward: -0.7433 | Loss: 3.6774
# Iters: 700 | Global MA Reward: 1.1125 | AVG Episode Reward: 2.3 | Loss: 1.3423
# Iters: 800 | Global MA Reward: 1.0812 | AVG Episode Reward: 1.8233 | Loss: 2.9945
# Iters: 900 | Global MA Reward: 1.334 | AVG Episode Reward: 1.37 | Loss: 5.573
# Iters: 1000 | Global MA Reward: 1.3775 | AVG Episode Reward: 1.5133 | Loss: 1.5617
# Iters: 1100 | Global MA Reward: 0.9592 | AVG Episode Reward: -2.7233 | Loss: -1.9287
# Iters: 1200 | Global MA Reward: 0.9644 | AVG Episode Reward: 0.2033 | Loss: -1.1968
# Iters: 1300 | Global MA Reward: 0.7814 | AVG Episode Reward: 2.03 | Loss: -0.7827
# Iters: 1400 | Global MA Reward: 0.9694 | AVG Episode Reward: -3.69 | Loss: 4.3724
# Iters: 1500 | Global MA Reward: 0.971 | AVG Episode Reward: -1.3067 | Loss: 2.6727
# Iters: 1600 | Global MA Reward: 0.6033 | AVG Episode Reward: -0.37 | Loss: 3.7191
# Iters: 1700 | Global MA Reward: 0.6993 | AVG Episode Reward: 2.61 | Loss: 5.4996
# Iters: 1800 | Global MA Reward: 0.9231 | AVG Episode Reward: -0.8133 | Loss: 1.5684
# Iters: 1900 | Global MA Reward: 1.6626 | AVG Episode Reward: 2.3033 | Loss: 3.4384
# Iters: 2000 | Global MA Reward: 1.5924 | AVG Episode Reward: 1.3233 | Loss: -1.9755
# ++++++++++++++++++ best reward= 1.8136 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.8195 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.8283 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.8496 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.8759 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.8912 ++++++++++++++++++++++
# Iters: 2100 | Global MA Reward: 1.8986 | AVG Episode Reward: 8.6 | Loss: -0.4158
# ++++++++++++++++++ best reward= 1.8986 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.9013 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.92 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.9216 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.9297 ++++++++++++++++++++++
# Iters: 2200 | Global MA Reward: 1.7248 | AVG Episode Reward: 0.5233 | Loss: -3.2698
# ++++++++++++++++++ best reward= 1.9521 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.9694 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 1.9774 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.002 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0221 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0448 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0585 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0628 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0642 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0756 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0953 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0957 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.0979 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1031 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1156 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1364 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1378 ++++++++++++++++++++++
# Iters: 2300 | Global MA Reward: 1.994 | AVG Episode Reward: 0.3333 | Loss: -3.6114
# Iters: 2400 | Global MA Reward: 1.696 | AVG Episode Reward: 2.64 | Loss: 2.9026
# Iters: 2500 | Global MA Reward: 1.714 | AVG Episode Reward: 0.7567 | Loss: 4.2896
# Iters: 2600 | Global MA Reward: 1.8462 | AVG Episode Reward: 0.7167 | Loss: -1.1942
# Iters: 2700 | Global MA Reward: 1.8765 | AVG Episode Reward: -0.2333 | Loss: 0.3769
# Iters: 2800 | Global MA Reward: 1.3333 | AVG Episode Reward: 0.92 | Loss: 3.088
# Iters: 2900 | Global MA Reward: 1.5591 | AVG Episode Reward: -0.16 | Loss: 0.3083
# Iters: 3000 | Global MA Reward: 1.8184 | AVG Episode Reward: 1.0167 | Loss: -2.4402
# Iters: 3100 | Global MA Reward: 1.7981 | AVG Episode Reward: -0.3133 | Loss: 0.9278
# Iters: 3200 | Global MA Reward: 2.0646 | AVG Episode Reward: 3.6467 | Loss: -0.8021
# ++++++++++++++++++ best reward= 2.1446 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1512 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.153 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1604 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1707 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1757 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1825 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1939 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.195 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.1983 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.2002 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.2244 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.2331 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.2476 ++++++++++++++++++++++
# Iters: 3300 | Global MA Reward: 2.1752 | AVG Episode Reward: 0.3467 | Loss: -3.7359
# Iters: 3400 | Global MA Reward: 1.955 | AVG Episode Reward: 1.7933 | Loss: -0.0124
# Iters: 3500 | Global MA Reward: 1.6911 | AVG Episode Reward: 0.2733 | Loss: 1.0166
# Iters: 3600 | Global MA Reward: 2.1432 | AVG Episode Reward: 3.6767 | Loss: -1.6063
# ++++++++++++++++++ best reward= 2.253 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.2574 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.2708 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.2939 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.3015 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.3214 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.3253 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.3353 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.3356 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.3484 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.3658 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.3748 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.4068 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.4228 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.4289 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.4441 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.4466 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.4476 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.4747 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.4794 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.496 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.51 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.513 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.5242 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.5368 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.5427 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.5705 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.5845 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.6119 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.6219 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.6317 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.6658 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.6665 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.6808 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.6988 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.707 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7418 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7533 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7583 ++++++++++++++++++++++
# Iters: 3700 | Global MA Reward: 2.7385 | AVG Episode Reward: 3.6867 | Loss: 0.2392
# ++++++++++++++++++ best reward= 2.7614 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7682 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7774 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7884 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7894 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7897 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.7959 ++++++++++++++++++++++
# Iters: 3800 | Global MA Reward: 2.6649 | AVG Episode Reward: 2.7167 | Loss: 1.0883
# Iters: 3900 | Global MA Reward: 2.4677 | AVG Episode Reward: 3.2033 | Loss: 6.6216
# Iters: 4000 | Global MA Reward: 2.5715 | AVG Episode Reward: 4.94 | Loss: 1.4967
# ++++++++++++++++++ best reward= 2.799 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8121 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8205 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8267 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8364 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8402 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8464 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8499 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.875 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8764 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.8934 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9089 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.909 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9267 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9512 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9539 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9544 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9581 ++++++++++++++++++++++
# Iters: 4100 | Global MA Reward: 2.9497 | AVG Episode Reward: 3.3333 | Loss: -1.7647
# ++++++++++++++++++ best reward= 2.9594 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9753 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9926 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9942 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 2.9998 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.0109 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.0191 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.0476 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.053 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.0554 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.0626 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.0709 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.0906 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.1038 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.1288 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.1319 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.1491 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.153 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.1633 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.1846 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2057 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2118 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2158 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2419 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2423 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2472 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2476 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2557 ++++++++++++++++++++++
# Iters: 4200 | Global MA Reward: 3.1379 | AVG Episode Reward: 3.89 | Loss: 2.0673
# Iters: 4300 | Global MA Reward: 2.7733 | AVG Episode Reward: 2.64 | Loss: 0.1588
# Iters: 4400 | Global MA Reward: 2.8848 | AVG Episode Reward: 5.17 | Loss: 2.501
# Iters: 4500 | Global MA Reward: 3.1605 | AVG Episode Reward: 4.0833 | Loss: 3.5948
# ++++++++++++++++++ best reward= 3.2582 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.2739 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.283 ++++++++++++++++++++++
# Iters: 4600 | Global MA Reward: 3.1065 | AVG Episode Reward: 5.53 | Loss: -2.8562
# Iters: 4700 | Global MA Reward: 3.1422 | AVG Episode Reward: 0.8933 | Loss: -2.4164
# ++++++++++++++++++ best reward= 3.3064 ++++++++++++++++++++++
# Iters: 4800 | Global MA Reward: 3.1418 | AVG Episode Reward: 1.8733 | Loss: 1.5513
# ++++++++++++++++++ best reward= 3.313 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.3199 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.3375 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.3546 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.3823 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.3839 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.3879 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.3884 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.4048 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.4083 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.4087 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.4406 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.4638 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.487 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.4986 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.5091 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.525 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.5495 ++++++++++++++++++++++
# Iters: 4900 | Global MA Reward: 3.5001 | AVG Episode Reward: 3.2 | Loss: 3.9513
# ++++++++++++++++++ best reward= 3.5512 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.5754 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.5906 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.5914 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.5987 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6001 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6191 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.629 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6323 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6383 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6392 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6434 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.657 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6616 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6627 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.6632 ++++++++++++++++++++++
# Iters: 5000 | Global MA Reward: 3.6534 | AVG Episode Reward: 5.4733 | Loss: -1.9486
# ++++++++++++++++++ best reward= 3.686 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.7095 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.718 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.7247 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.741 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.7467 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.7533 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.7541 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.7578 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.7887 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.7897 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.81 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.8254 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.8669 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.8789 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.8801 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.9132 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.9197 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.9515 ++++++++++++++++++++++
# Iters: 5100 | Global MA Reward: 3.8638 | AVG Episode Reward: 3.67 | Loss: 4.3856
# ++++++++++++++++++ best reward= 3.9557 ++++++++++++++++++++++
# Iters: 5200 | Global MA Reward: 3.6209 | AVG Episode Reward: -0.1333 | Loss: -4.5461
# Iters: 5300 | Global MA Reward: 3.5725 | AVG Episode Reward: 0.8867 | Loss: -1.6025
# ++++++++++++++++++ best reward= 3.966 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 3.9913 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.0002 ++++++++++++++++++++++
# Iters: 5400 | Global MA Reward: 3.9197 | AVG Episode Reward: 1.67 | Loss: 9.8551
# ++++++++++++++++++ best reward= 4.0218 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.0559 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.0801 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.0925 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.1193 ++++++++++++++++++++++
# Iters: 5500 | Global MA Reward: 3.9382 | AVG Episode Reward: 4.54 | Loss: 6.1273
# ++++++++++++++++++ best reward= 4.1213 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.1394 ++++++++++++++++++++++
# Iters: 5600 | Global MA Reward: 4.119 | AVG Episode Reward: 3.0667 | Loss: 4.8145
# ++++++++++++++++++ best reward= 4.148 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.166 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.1676 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.1893 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.2292 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.2431 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.2526 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.2588 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.2945 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.3673 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.4016 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.4379 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.4639 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.4657 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.4993 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.5379 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.5395 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.5813 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.6084 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.6119 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.6308 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.6472 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.6538 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.6666 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.698 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.7091 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.7421 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.7546 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.7631 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.7867 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.7923 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.8137 ++++++++++++++++++++++
# Iters: 5700 | Global MA Reward: 4.8468 | AVG Episode Reward: 9.3333 | Loss: 1.2595
# ++++++++++++++++++ best reward= 4.8468 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.8827 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.8968 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.9306 ++++++++++++++++++++++
# Iters: 5800 | Global MA Reward: 4.9431 | AVG Episode Reward: 6.3567 | Loss: 4.0366
# ++++++++++++++++++ best reward= 4.9431 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.9597 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.963 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.9851 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.9867 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 4.995 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0034 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0217 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0233 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0284 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0547 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0703 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0814 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0833 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.0963 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.1007 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.1039 ++++++++++++++++++++++
# Iters: 5900 | Global MA Reward: 5.0334 | AVG Episode Reward: 3.8967 | Loss: -0.275
# ++++++++++++++++++ best reward= 5.1053 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.1205 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.1366 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.146 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.1589 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.1624 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.1657 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.1734 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.2076 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.2402 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.2433 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.2554 ++++++++++++++++++++++
# Iters: 6000 | Global MA Reward: 5.2411 | AVG Episode Reward: 3.8167 | Loss: 2.52
# ++++++++++++++++++ best reward= 5.2599 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.2746 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.2946 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.3124 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.3327 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.3382 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.3477 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.3506 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.3711 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.3992 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.4257 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.4318 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.4508 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.4542 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.4712 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.4964 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.5099 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.5548 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.5599 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.5794 ++++++++++++++++++++++
# Iters: 6100 | Global MA Reward: 5.3975 | AVG Episode Reward: 3.96 | Loss: -4.1674
# ++++++++++++++++++ best reward= 5.5884 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6039 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6256 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6289 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6375 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6381 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6596 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6826 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6938 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.6959 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.7012 ++++++++++++++++++++++
# Iters: 6200 | Global MA Reward: 5.5458 | AVG Episode Reward: 3.61 | Loss: 1.9147
# Iters: 6300 | Global MA Reward: 5.6993 | AVG Episode Reward: 5.7233 | Loss: 8.4897
# ++++++++++++++++++ best reward= 5.7324 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.7356 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.7545 ++++++++++++++++++++++
# Iters: 6400 | Global MA Reward: 5.5088 | AVG Episode Reward: 5.4767 | Loss: 2.4108
# Iters: 6500 | Global MA Reward: 5.2572 | AVG Episode Reward: 4.88 | Loss: 2.7484
# Iters: 6600 | Global MA Reward: 5.4318 | AVG Episode Reward: 6.9867 | Loss: -1.0065
# Iters: 6700 | Global MA Reward: 5.4266 | AVG Episode Reward: 4.1533 | Loss: 0.4444
# Iters: 6800 | Global MA Reward: 5.6815 | AVG Episode Reward: 6.9267 | Loss: 5.463
# ++++++++++++++++++ best reward= 5.7549 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.7782 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.7847 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.7946 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.822 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.8257 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.8455 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.8601 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.8602 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.8685 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.895 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.9015 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.9045 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.9315 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.9401 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.9674 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.9897 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.9951 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 5.9983 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.0185 ++++++++++++++++++++++
# Iters: 6900 | Global MA Reward: 5.9676 | AVG Episode Reward: 6.67 | Loss: -2.3436
# Iters: 7000 | Global MA Reward: 5.8641 | AVG Episode Reward: 5.2033 | Loss: 3.6748
# Iters: 7100 | Global MA Reward: 5.7153 | AVG Episode Reward: 7.37 | Loss: 1.124
# Iters: 7200 | Global MA Reward: 5.7908 | AVG Episode Reward: 7.2 | Loss: 1.4873
# ++++++++++++++++++ best reward= 6.0278 ++++++++++++++++++++++
# Iters: 7300 | Global MA Reward: 5.9372 | AVG Episode Reward: 7.4033 | Loss: 7.1504
# ++++++++++++++++++ best reward= 6.031 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.0486 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.0574 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.0691 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.0867 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.1036 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.1075 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.1147 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.1348 ++++++++++++++++++++++
# Iters: 7400 | Global MA Reward: 6.0879 | AVG Episode Reward: 4.54 | Loss: 2.1727
# ++++++++++++++++++ best reward= 6.1535 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.1564 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.1695 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.1812 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.1971 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.2226 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.2366 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.256 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.259 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.2738 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.2806 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.2877 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.2894 ++++++++++++++++++++++
# Iters: 7500 | Global MA Reward: 6.1936 | AVG Episode Reward: 7.4433 | Loss: -3.7636
# Iters: 7600 | Global MA Reward: 6.2233 | AVG Episode Reward: 5.28 | Loss: 1.4235
# ++++++++++++++++++ best reward= 6.2949 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.3036 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.3163 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.3295 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.337 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.3477 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.3539 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.3725 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.3761 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.3863 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4041 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4045 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.406 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4129 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4283 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4342 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4352 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4457 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4771 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.4831 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.502 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.5087 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.5104 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.5233 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.5611 ++++++++++++++++++++++
# Iters: 7700 | Global MA Reward: 6.4994 | AVG Episode Reward: 6.92 | Loss: 1.7706
# ++++++++++++++++++ best reward= 6.5853 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.5926 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.5974 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.6288 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.6408 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.6518 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.6571 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.6664 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.678 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.7022 ++++++++++++++++++++++
# Iters: 7800 | Global MA Reward: 6.6302 | AVG Episode Reward: 7.8867 | Loss: 3.0454
# Iters: 7900 | Global MA Reward: 6.5252 | AVG Episode Reward: 6.3867 | Loss: -1.8266
# ++++++++++++++++++ best reward= 6.7097 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.7298 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.7397 ++++++++++++++++++++++
# Iters: 8000 | Global MA Reward: 6.6393 | AVG Episode Reward: 5.09 | Loss: 0.4689
# Iters: 8100 | Global MA Reward: 6.6161 | AVG Episode Reward: 6.7567 | Loss: 2.9735
# Iters: 8200 | Global MA Reward: 6.6081 | AVG Episode Reward: 6.82 | Loss: -1.8529
# ++++++++++++++++++ best reward= 6.7401 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.7507 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.755 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.7777 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.7826 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.7934 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.8106 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.8226 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.8421 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.8565 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.8676 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.8875 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.8981 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9049 ++++++++++++++++++++++
# Iters: 8300 | Global MA Reward: 6.9022 | AVG Episode Reward: 8.74 | Loss: -1.2923
# ++++++++++++++++++ best reward= 6.9289 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9306 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9318 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9342 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9369 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9496 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9617 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9875 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 6.9941 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0034 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0122 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0181 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0254 ++++++++++++++++++++++
# Iters: 8400 | Global MA Reward: 7.0008 | AVG Episode Reward: 6.1567 | Loss: -1.6169
# Iters: 8500 | Global MA Reward: 6.6957 | AVG Episode Reward: 6.82 | Loss: -0.0001
# Iters: 8600 | Global MA Reward: 6.9149 | AVG Episode Reward: 6.4233 | Loss: -1.5998
# ++++++++++++++++++ best reward= 7.0269 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0341 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0371 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0408 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0433 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0493 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0589 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0591 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0708 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.077 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0872 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.0889 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1054 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1236 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1284 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1349 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.144 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1452 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.151 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1663 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1901 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1985 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.1986 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.2105 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.2335 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.2377 ++++++++++++++++++++++
# Iters: 8700 | Global MA Reward: 7.1238 | AVG Episode Reward: 4.6067 | Loss: 3.9707
# Iters: 8800 | Global MA Reward: 7.0314 | AVG Episode Reward: 7.52 | Loss: 4.1311
# Iters: 8900 | Global MA Reward: 7.0989 | AVG Episode Reward: 7.4733 | Loss: 0.6245
# Iters: 9000 | Global MA Reward: 7.182 | AVG Episode Reward: 6.4233 | Loss: 3.3296
# ++++++++++++++++++ best reward= 7.2538 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.2583 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.2747 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.2762 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.2859 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.2949 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3014 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3046 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3164 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3287 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3472 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3507 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3543 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3581 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3608 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3768 ++++++++++++++++++++++
# Iters: 9100 | Global MA Reward: 7.3793 | AVG Episode Reward: 7.6267 | Loss: 0.0382
# ++++++++++++++++++ best reward= 7.3793 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3876 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.3989 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.4017 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.4129 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.4279 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.4471 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.4588 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.4655 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.478 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.4792 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5005 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5077 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5202 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5384 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5424 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5428 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5457 ++++++++++++++++++++++
# Iters: 9200 | Global MA Reward: 7.4099 | AVG Episode Reward: 7.9333 | Loss: 1.9144
# ++++++++++++++++++ best reward= 7.5652 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5711 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.582 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5822 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5868 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.5906 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6014 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6247 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6358 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6413 ++++++++++++++++++++++
# Iters: 9300 | Global MA Reward: 7.5348 | AVG Episode Reward: 6.7267 | Loss: 0.5225
# ++++++++++++++++++ best reward= 7.6449 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6539 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6623 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6695 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6711 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6769 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.6793 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.7037 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.7114 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.736 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.7516 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.7545 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.7574 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.7594 ++++++++++++++++++++++
# Iters: 9400 | Global MA Reward: 7.496 | AVG Episode Reward: 8.58 | Loss: 0.301
# Iters: 9500 | Global MA Reward: 7.6644 | AVG Episode Reward: 9.61 | Loss: -0.1194
# Iters: 9600 | Global MA Reward: 7.5951 | AVG Episode Reward: 8.1667 | Loss: 0.0805
# Iters: 9700 | Global MA Reward: 7.6188 | AVG Episode Reward: 7.43 | Loss: -0.8324
# ++++++++++++++++++ best reward= 7.768 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.7823 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.7989 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8116 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8191 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8249 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8328 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8416 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8477 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8757 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8786 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.8837 ++++++++++++++++++++++
# Iters: 9800 | Global MA Reward: 7.7554 | AVG Episode Reward: 7.7033 | Loss: 2.3265
# Iters: 9900 | Global MA Reward: 7.8344 | AVG Episode Reward: 7.55 | Loss: 1.5101
# ++++++++++++++++++ best reward= 7.889 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9045 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9092 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9192 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9296 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9523 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9581 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9652 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9714 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9733 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9745 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 7.9889 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.0024 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.006 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.0353 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.0416 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.0596 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.0806 ++++++++++++++++++++++
# Iters: 10000 | Global MA Reward: 8.0439 | AVG Episode Reward: 6.8133 | Loss: -3.8749
# Iters: 10100 | Global MA Reward: 7.9859 | AVG Episode Reward: 5.9167 | Loss: 0.5429
# ++++++++++++++++++ best reward= 8.1136 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.1145 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.1553 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.162 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.1784 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2257 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2278 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2305 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2353 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.245 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2452 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2533 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2618 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2803 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.2827 ++++++++++++++++++++++
# Iters: 10200 | Global MA Reward: 8.1131 | AVG Episode Reward: 9.5333 | Loss: -4.8617
# Iters: 10300 | Global MA Reward: 8.2965 | AVG Episode Reward: 10.9067 | Loss: 0.9199
# ++++++++++++++++++ best reward= 8.2965 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.297 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3108 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3247 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3309 ++++++++++++++++++++++
# Iters: 10400 | Global MA Reward: 8.1398 | AVG Episode Reward: 8.6567 | Loss: 1.0058
# Iters: 10500 | Global MA Reward: 8.1815 | AVG Episode Reward: 8.8567 | Loss: 2.584
# Iters: 10600 | Global MA Reward: 8.3143 | AVG Episode Reward: 9.8033 | Loss: 1.8443
# ++++++++++++++++++ best reward= 8.3341 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3414 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.348 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3532 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3548 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3725 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3855 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3898 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.3988 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4004 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4011 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4132 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4195 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4224 ++++++++++++++++++++++
# Iters: 10700 | Global MA Reward: 8.2911 | AVG Episode Reward: 9.26 | Loss: 1.6192
# Iters: 10800 | Global MA Reward: 8.3191 | AVG Episode Reward: 6.4667 | Loss: 1.6265
# Iters: 10900 | Global MA Reward: 8.342 | AVG Episode Reward: 6.93 | Loss: 0.6696
# ++++++++++++++++++ best reward= 8.4294 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.433 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4392 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.448 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4594 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4691 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4703 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4762 ++++++++++++++++++++++
# Iters: 11000 | Global MA Reward: 8.469 | AVG Episode Reward: 7.7533 | Loss: 0.7513
# ++++++++++++++++++ best reward= 8.4812 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4856 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.4857 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5033 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5104 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5196 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5241 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5418 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5525 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.553 ++++++++++++++++++++++
# Iters: 11100 | Global MA Reward: 8.49 | AVG Episode Reward: 9.8467 | Loss: 0.0553
# Iters: 11200 | Global MA Reward: 8.4507 | AVG Episode Reward: 7.9233 | Loss: 1.6306
# Iters: 11300 | Global MA Reward: 8.4013 | AVG Episode Reward: 6.49 | Loss: -1.5548
# ++++++++++++++++++ best reward= 8.5574 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.575 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5779 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5795 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5915 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.5966 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6028 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6058 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6098 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6148 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6336 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6418 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6563 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6615 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.667 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.6858 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.7118 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.7133 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.7381 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.7668 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.7729 ++++++++++++++++++++++
# Iters: 11400 | Global MA Reward: 8.6632 | AVG Episode Reward: 8.8233 | Loss: 4.7447
# Iters: 11500 | Global MA Reward: 8.5526 | AVG Episode Reward: 8.22 | Loss: 1.2327
# Iters: 11600 | Global MA Reward: 8.6111 | AVG Episode Reward: 6.6333 | Loss: -0.5075
# ++++++++++++++++++ best reward= 8.7858 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.7867 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.7968 ++++++++++++++++++++++
# Iters: 11700 | Global MA Reward: 8.7279 | AVG Episode Reward: 9.1633 | Loss: 0.5405
# ++++++++++++++++++ best reward= 8.8174 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.8471 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.8573 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.8607 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.8617 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.8659 ++++++++++++++++++++++
# Iters: 11800 | Global MA Reward: 8.8492 | AVG Episode Reward: 8.4233 | Loss: -0.5845
# ++++++++++++++++++ best reward= 8.8687 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.874 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.8959 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.9162 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.919 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.9247 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.943 ++++++++++++++++++++++
# ++++++++++++++++++ best reward= 8.949 ++++++++++++++++++++++
# Iters: 11900 | Global MA Reward: 8.7087 | AVG Episode Reward: 9.84 | Loss: 3.389
# Iters: 12000 | Global MA Reward: 8.689 | AVG Episode Reward: 11.0467 | Loss: -0.0963
# ...
# Iters: 44200 | Global MA Reward: 11.0535 | AVG Episode Reward: 11.4667 | Loss: -0.2681
# Iters: 44300 | Global MA Reward: 10.9756 | AVG Episode Reward: 9.0033 | Loss: 1.4484
# Iters: 44400 | Global MA Reward: 10.7627 | AVG Episode Reward: 12.4767 | Loss: -2.2868
# Iters: 44500 | Global MA Reward: 10.8343 | AVG Episode Reward: 10.13 | Loss: -0.5909
# Iters: 44600 | Global MA Reward: 10.8112 | AVG Episode Reward: 13.7 | Loss: 0.92
# Iters: 44700 | Global MA Reward: 10.8862 | AVG Episode Reward: 11.54 | Loss: -1.6607
# Iters: 44800 | Global MA Reward: 10.713 | AVG Episode Reward: 13.1767 | Loss: 1.0398
# Iters: 44900 | Global MA Reward: 10.6571 | AVG Episode Reward: 11.8967 | Loss: -2.9568
# Iters: 45000 | Global MA Reward: 11.0006 | AVG Episode Reward: 9.74 | Loss: -2.084
# Iters: 45100 | Global MA Reward: 11.0812 | AVG Episode Reward: 13.46 | Loss: 0.8542
# Iters: 45200 | Global MA Reward: 11.0657 | AVG Episode Reward: 11.4933 | Loss: -0.1092
# Iters: 45300 | Global MA Reward: 10.9445 | AVG Episode Reward: 15.28 | Loss: 0.241
# Iters: 45400 | Global MA Reward: 10.8932 | AVG Episode Reward: 11.5567 | Loss: 2.3414
# Iters: 45500 | Global MA Reward: 11.0459 | AVG Episode Reward: 10.83 | Loss: 0.4688
# Iters: 45600 | Global MA Reward: 10.9085 | AVG Episode Reward: 12.1867 | Loss: -0.0798
# Iters: 45700 | Global MA Reward: 11.0683 | AVG Episode Reward: 12.9667 | Loss: -1.0499
# Iters: 45800 | Global MA Reward: 10.9354 | AVG Episode Reward: 10.45 | Loss: -1.3246
# Iters: 45900 | Global MA Reward: 10.9643 | AVG Episode Reward: 10.6067 | Loss: -0.0399
# Iters: 46000 | Global MA Reward: 10.7437 | AVG Episode Reward: 12.6767 | Loss: 1.5834
# Iters: 46100 | Global MA Reward: 10.9837 | AVG Episode Reward: 10.34 | Loss: -4.0156
# Iters: 46200 | Global MA Reward: 11.0302 | AVG Episode Reward: 11.3533 | Loss: 7.7516
# Iters: 46300 | Global MA Reward: 10.9416 | AVG Episode Reward: 8.86 | Loss: 0.2842
# Iters: 46400 | Global MA Reward: 11.1255 | AVG Episode Reward: 10.3067 | Loss: 16.3118
# Iters: 46500 | Global MA Reward: 11.0224 | AVG Episode Reward: 10.69 | Loss: -1.6743
# Iters: 46600 | Global MA Reward: 10.8375 | AVG Episode Reward: 10.64 | Loss: 3.408
# Iters: 46700 | Global MA Reward: 11.0 | AVG Episode Reward: 11.6267 | Loss: -0.6527
# Iters: 46800 | Global MA Reward: 10.9757 | AVG Episode Reward: 7.57 | Loss: -1.1804
# Iters: 46900 | Global MA Reward: 10.773 | AVG Episode Reward: 8.14 | Loss: -0.7267
# Iters: 47000 | Global MA Reward: 10.8716 | AVG Episode Reward: 11.0 | Loss: 1.5861
# Iters: 47100 | Global MA Reward: 11.1809 | AVG Episode Reward: 9.1833 | Loss: 1.4857
# Iters: 47200 | Global MA Reward: 11.2716 | AVG Episode Reward: 13.2367 | Loss: 2.9307
# Iters: 47300 | Global MA Reward: 11.2298 | AVG Episode Reward: 10.6633 | Loss: 1.8934
# Iters: 47400 | Global MA Reward: 11.2292 | AVG Episode Reward: 10.1933 | Loss: 0.4667
# Iters: 47500 | Global MA Reward: 10.9495 | AVG Episode Reward: 8.1333 | Loss: 0.9979
# Iters: 47600 | Global MA Reward: 10.948 | AVG Episode Reward: 10.2867 | Loss: 1.7503
# Iters: 47700 | Global MA Reward: 10.8208 | AVG Episode Reward: 10.3767 | Loss: 2.6088
# Iters: 47800 | Global MA Reward: 10.9972 | AVG Episode Reward: 14.62 | Loss: 4.7911
# Iters: 47900 | Global MA Reward: 11.0266 | AVG Episode Reward: 10.48 | Loss: -3.4059
# Iters: 48000 | Global MA Reward: 10.9143 | AVG Episode Reward: 9.0433 | Loss: 1.2448
# Iters: 48100 | Global MA Reward: 11.0109 | AVG Episode Reward: 10.4633 | Loss: -2.4796
# Iters: 48200 | Global MA Reward: 10.9747 | AVG Episode Reward: 11.95 | Loss: -1.7081
# Iters: 48300 | Global MA Reward: 11.017 | AVG Episode Reward: 10.1233 | Loss: 0.4707
# Iters: 48400 | Global MA Reward: 11.0234 | AVG Episode Reward: 9.9133 | Loss: -2.0892
# Iters: 48500 | Global MA Reward: 10.9949 | AVG Episode Reward: 11.2067 | Loss: 0.8705
# Iters: 48600 | Global MA Reward: 10.9943 | AVG Episode Reward: 11.8933 | Loss: 0.9174
# Iters: 48700 | Global MA Reward: 10.7375 | AVG Episode Reward: 10.6033 | Loss: -3.3382
# Iters: 48800 | Global MA Reward: 10.9062 | AVG Episode Reward: 10.9767 | Loss: 4.0349
# Iters: 48900 | Global MA Reward: 10.7682 | AVG Episode Reward: 9.7333 | Loss: 1.6311
# Iters: 49000 | Global MA Reward: 10.838 | AVG Episode Reward: 10.36 | Loss: 1.1584
# Iters: 49100 | Global MA Reward: 10.9186 | AVG Episode Reward: 11.87 | Loss: -2.4148
# Iters: 49200 | Global MA Reward: 10.9806 | AVG Episode Reward: 9.7533 | Loss: -1.6669
# Iters: 49300 | Global MA Reward: 11.0114 | AVG Episode Reward: 14.04 | Loss: 1.8313
# Iters: 49400 | Global MA Reward: 11.0094 | AVG Episode Reward: 9.8533 | Loss: 5.7335
# Iters: 49500 | Global MA Reward: 10.9016 | AVG Episode Reward: 12.85 | Loss: 1.4301
# Iters: 49600 | Global MA Reward: 10.9732 | AVG Episode Reward: 7.4333 | Loss: 1.1605
# Iters: 49700 | Global MA Reward: 10.7611 | AVG Episode Reward: 11.3467 | Loss: -0.494
# Iters: 49800 | Global MA Reward: 10.5442 | AVG Episode Reward: 8.7067 | Loss: 3.0866
# Iters: 49900 | Global MA Reward: 10.6948 | AVG Episode Reward: 9.4533 | Loss: -0.5543
# Iters: 50000 | Global MA Reward: 10.69 | AVG Episode Reward: 12.8233 | Loss: 3.3738
# Iters: 50100 | Global MA Reward: 10.5887 | AVG Episode Reward: 9.8733 | Loss: 0.4858
# Iters: 50200 | Global MA Reward: 10.8062 | AVG Episode Reward: 12.55 | Loss: 1.3186
# Iters: 50300 | Global MA Reward: 10.9652 | AVG Episode Reward: 12.3367 | Loss: 12.5412
# Iters: 50400 | Global MA Reward: 10.8512 | AVG Episode Reward: 9.6433 | Loss: 2.9768
# Iters: 50500 | Global MA Reward: 10.7928 | AVG Episode Reward: 9.3433 | Loss: -2.9553
# Iters: 50600 | Global MA Reward: 10.8356 | AVG Episode Reward: 9.39 | Loss: 0.9691
# Iters: 50700 | Global MA Reward: 10.9639 | AVG Episode Reward: 10.8933 | Loss: -0.6904
# Iters: 50800 | Global MA Reward: 11.0353 | AVG Episode Reward: 10.5367 | Loss: -3.9133
# Iters: 50900 | Global MA Reward: 11.0175 | AVG Episode Reward: 14.8367 | Loss: -0.7063
# Iters: 51000 | Global MA Reward: 11.048 | AVG Episode Reward: 10.8 | Loss: -0.0957
# Iters: 51100 | Global MA Reward: 10.9685 | AVG Episode Reward: 12.6333 | Loss: 2.2652
# Iters: 51200 | Global MA Reward: 11.0468 | AVG Episode Reward: 11.8967 | Loss: 13.5867
# Iters: 51300 | Global MA Reward: 10.9175 | AVG Episode Reward: 11.0467 | Loss: 3.964
# Iters: 51400 | Global MA Reward: 10.7333 | AVG Episode Reward: 13.3 | Loss: 5.3996
# Iters: 51500 | Global MA Reward: 11.0661 | AVG Episode Reward: 12.0733 | Loss: 0.9435
# Iters: 51600 | Global MA Reward: 11.0719 | AVG Episode Reward: 8.5 | Loss: -2.6661
# Iters: 51700 | Global MA Reward: 11.2039 | AVG Episode Reward: 14.3633 | Loss: -1.3882
# Iters: 51800 | Global MA Reward: 11.0508 | AVG Episode Reward: 10.24 | Loss: 0.5801
# Iters: 51900 | Global MA Reward: 10.794 | AVG Episode Reward: 8.25 | Loss: -3.1331
# Iters: 52000 | Global MA Reward: 10.8852 | AVG Episode Reward: 10.3167 | Loss: 5.1862
# Iters: 52100 | Global MA Reward: 10.8163 | AVG Episode Reward: 10.2533 | Loss: -4.7141
# Iters: 52200 | Global MA Reward: 10.9693 | AVG Episode Reward: 11.7467 | Loss: 6.5968
# Iters: 52300 | Global MA Reward: 10.8423 | AVG Episode Reward: 10.9467 | Loss: -1.5574
# Iters: 52400 | Global MA Reward: 11.0216 | AVG Episode Reward: 13.6733 | Loss: 2.3484
# Iters: 52500 | Global MA Reward: 10.9625 | AVG Episode Reward: 10.4267 | Loss: -1.5763
# Iters: 52600 | Global MA Reward: 10.7904 | AVG Episode Reward: 10.8267 | Loss: 1.0535
# Iters: 52700 | Global MA Reward: 10.8347 | AVG Episode Reward: 10.35 | Loss: 3.3854
# Iters: 52800 | Global MA Reward: 10.985 | AVG Episode Reward: 9.22 | Loss: 4.9048
# Iters: 52900 | Global MA Reward: 11.0147 | AVG Episode Reward: 11.4133 | Loss: -0.8828
# Iters: 53000 | Global MA Reward: 10.7278 | AVG Episode Reward: 9.24 | Loss: 0.7922
# Iters: 53100 | Global MA Reward: 10.6703 | AVG Episode Reward: 12.8967 | Loss: 4.3425
# Iters: 53200 | Global MA Reward: 10.6575 | AVG Episode Reward: 8.7567 | Loss: -0.7172
# Iters: 53300 | Global MA Reward: 10.7516 | AVG Episode Reward: 11.3433 | Loss: 5.7732
# Iters: 53400 | Global MA Reward: 10.435 | AVG Episode Reward: 12.73 | Loss: -1.0379
# Iters: 53500 | Global MA Reward: 10.5962 | AVG Episode Reward: 11.6567 | Loss: -1.8244
# Iters: 53600 | Global MA Reward: 10.9182 | AVG Episode Reward: 20.36 | Loss: -0.0541
# Iters: 53700 | Global MA Reward: 10.5049 | AVG Episode Reward: 9.3333 | Loss: 3.5676
# Iters: 53800 | Global MA Reward: 10.6665 | AVG Episode Reward: 8.2267 | Loss: 0.3039
# Iters: 53900 | Global MA Reward: 10.8732 | AVG Episode Reward: 9.92 | Loss: -2.5181
# Iters: 54000 | Global MA Reward: 10.8114 | AVG Episode Reward: 13.8667 | Loss: -1.5498
# Iters: 54100 | Global MA Reward: 10.4633 | AVG Episode Reward: 6.5533 | Loss: -1.2889
# Iters: 54200 | Global MA Reward: 10.5326 | AVG Episode Reward: 11.9633 | Loss: 0.1827
# Iters: 54300 | Global MA Reward: 10.442 | AVG Episode Reward: 10.0867 | Loss: -4.2708
# Iters: 54400 | Global MA Reward: 10.7716 | AVG Episode Reward: 9.9967 | Loss: 2.6297
# Iters: 54500 | Global MA Reward: 10.8315 | AVG Episode Reward: 7.2967 | Loss: -1.0162
# Iters: 54600 | Global MA Reward: 10.835 | AVG Episode Reward: 10.7767 | Loss: -4.0643
# Iters: 54700 | Global MA Reward: 10.756 | AVG Episode Reward: 13.12 | Loss: 0.4463
# Iters: 54800 | Global MA Reward: 10.7507 | AVG Episode Reward: 12.42 | Loss: -2.4491
# Iters: 54900 | Global MA Reward: 10.5054 | AVG Episode Reward: 11.02 | Loss: 0.6655
# Iters: 55000 | Global MA Reward: 10.5307 | AVG Episode Reward: 10.7267 | Loss: 5.2981
# Iters: 55100 | Global MA Reward: 10.8489 | AVG Episode Reward: 12.7433 | Loss: -0.3586
# Iters: 55200 | Global MA Reward: 10.7489 | AVG Episode Reward: 9.4 | Loss: 1.4363
# Iters: 55300 | Global MA Reward: 10.607 | AVG Episode Reward: 9.08 | Loss: -2.8452
# Iters: 55400 | Global MA Reward: 10.9811 | AVG Episode Reward: 8.8967 | Loss: 2.8711
# Iters: 55500 | Global MA Reward: 10.938 | AVG Episode Reward: 8.8267 | Loss: -0.9046
# Iters: 55600 | Global MA Reward: 10.8239 | AVG Episode Reward: 10.6667 | Loss: 2.1776
# Iters: 55700 | Global MA Reward: 10.6145 | AVG Episode Reward: 9.7767 | Loss: 6.0889
# Iters: 55800 | Global MA Reward: 10.9395 | AVG Episode Reward: 15.4133 | Loss: -3.0765
# Iters: 55900 | Global MA Reward: 11.0191 | AVG Episode Reward: 9.64 | Loss: 5.552
# Iters: 56000 | Global MA Reward: 10.8993 | AVG Episode Reward: 12.08 | Loss: 7.7508
# Iters: 56100 | Global MA Reward: 10.7422 | AVG Episode Reward: 6.99 | Loss: 1.6251
# Iters: 56200 | Global MA Reward: 10.6309 | AVG Episode Reward: 11.9167 | Loss: 2.9762
# Iters: 56300 | Global MA Reward: 10.3239 | AVG Episode Reward: 9.6833 | Loss: 2.4908
# Iters: 56400 | Global MA Reward: 10.5221 | AVG Episode Reward: 12.75 | Loss: 2.3409
# Iters: 56500 | Global MA Reward: 10.7952 | AVG Episode Reward: 13.05 | Loss: -2.2168
# Iters: 56600 | Global MA Reward: 10.7314 | AVG Episode Reward: 9.7533 | Loss: -1.5011
# Iters: 56700 | Global MA Reward: 10.5924 | AVG Episode Reward: 13.25 | Loss: -1.1143
# Iters: 56800 | Global MA Reward: 10.3529 | AVG Episode Reward: 8.17 | Loss: 2.8953
# Iters: 56900 | Global MA Reward: 10.3837 | AVG Episode Reward: 13.2533 | Loss: -0.2354
# Iters: 57000 | Global MA Reward: 10.4574 | AVG Episode Reward: 10.4867 | Loss: 16.4306
# Iters: 57100 | Global MA Reward: 10.7235 | AVG Episode Reward: 12.3133 | Loss: 0.2111
# Iters: 57200 | Global MA Reward: 10.673 | AVG Episode Reward: 9.55 | Loss: -0.1031
# Iters: 57300 | Global MA Reward: 10.6033 | AVG Episode Reward: 14.2433 | Loss: -1.1671
# Iters: 57400 | Global MA Reward: 10.595 | AVG Episode Reward: 11.7333 | Loss: 1.1966
# Iters: 57500 | Global MA Reward: 10.683 | AVG Episode Reward: 9.65 | Loss: 3.4557
# Iters: 57600 | Global MA Reward: 10.46 | AVG Episode Reward: 10.08 | Loss: 2.5267
# Iters: 57700 | Global MA Reward: 10.5164 | AVG Episode Reward: 11.1933 | Loss: 1.4605
# Iters: 57800 | Global MA Reward: 10.4818 | AVG Episode Reward: 11.15 | Loss: 2.7452
# Iters: 57900 | Global MA Reward: 10.6326 | AVG Episode Reward: 11.2733 | Loss: 2.2035
# Iters: 58000 | Global MA Reward: 10.6031 | AVG Episode Reward: 10.1667 | Loss: 2.8698
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-4-8e0b279d89d5> in record(iters, glob_reward, AC_loss)
#      85     """Helper function to store score and print statistics.
#      86     """
# ---> 87     avg_reward = np.mean([test_reward() for _ in range(3)])
#      88     #ep_reward = test_reward()
#      89
#
# <ipython-input-4-8e0b279d89d5> in <listcomp>(.0)
#      85     """Helper function to store score and print statistics.
#      86     """
# ---> 87     avg_reward = np.mean([test_reward() for _ in range(3)])
#      88     #ep_reward = test_reward()
#      89
#
# <ipython-input-4-8e0b279d89d5> in test_reward()
#      74     #print('testing...')
#      75     while not done:
# ---> 76         action_probs,_ = model_ActorCritic.predict_on_batch(state[None,:])
#      77         action = np.argmax(action_probs)
#      78         next_state, reward, done, _ = env.step(action)
#
# c:\users\a\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\engine\training.py in predict_on_batch(self, x)
#    1238     self._check_call_args('predict_on_batch')
#    1239     if self._experimental_run_tf_function:
# -> 1240       return training_v2_utils.predict_on_batch(self, x, standalone=True)
#    1241
#    1242     if (self._distribution_strategy and
#
# c:\users\a\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in predict_on_batch(model, x, standalone)
#     541   # If `model._distribution_strategy` is True, then we are in a replica context
#     542   # at this point.
# --> 543   inputs = training_utils.cast_to_model_input_dtypes(inputs, model)
#     544   if isinstance(inputs, collections.Sequence):
#     545     # Unwrap lists with only one input, as we do when training on batch
#
# c:\users\a\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in cast_to_model_input_dtypes(x, model)
#    1373   """
#    1374   input_dtypes = nest.map_structure(lambda t: t.dtype, model.inputs)
# -> 1375   return nest.map_structure(math_ops.cast, x, input_dtypes)
#    1376
#    1377
#
# c:\users\a\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# c:\users\a\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\util\nest.py in <listcomp>(.0)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# c:\users\a\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\a\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\math_ops.py in cast(x, dtype, name)
#     705       x = ops.convert_to_tensor(x, name="x")
#     706       if x.dtype.base_dtype != base_type:
# --> 707         x = gen_math_ops.cast(x, base_type, name=name)
#     708     if x.dtype.is_complex and base_type.is_floating:
#     709       logging.warn("Casting complex to real discards imaginary part.")
#
# c:\users\a\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in cast(x, DstT, Truncate, name)
#    1960       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    1961         _ctx._context_handle, tld.device_name, "Cast", name, tld.op_callbacks,
# -> 1962         x, "DstT", DstT, "Truncate", Truncate)
#    1963       return _result
#    1964     except _core._FallbackException:
#
# KeyboardInterrupt:
